# %% [markdown]
# ### Load your AWS Access Key/Secret.
#
# **Never paste your Key/Secret into the notebook. Never print your Key/Secret in the notebook. Never commit your Key/Secret to github.**

# %%
import os
myAccessKey = None
mySecretKey = None
def get_secrets():
    global myAccessKey
    global mySecretKey
    myAccessKey = os.environ['AWS_ACCESS_KEY_ID']
    mySecretKey = os.environ['AWS_SECRET_ACCESS_KEY']

get_secrets()

# %% [markdown]
# ### Set up the Spark Context and AWS S3 credentials
#
# Reference:
#
# [Connecting to PySpark from a Notebook](https://jupyter-docker-stacks.readthedocs.io/en/latest/using/specifics.html#in-a-python-notebook)
#
# [Using PySpark with AWS S3](https://jupyter-docker-stacks.readthedocs.io/en/latest/using/recipes.html#using-pyspark-with-aws-s3)

# %%
# this will take some time
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.amazonaws:aws-java-sdk:1.10.34,org.apache.hadoop:hadoop-aws:2.6.0 pyspark-shell'

import pyspark
sc = pyspark.SparkContext("local[*]")

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

hadoopConf = sc._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3.impl", "org.apache.hadoop.fs.s3native.NativeS3FileSystem")
hadoopConf.set("fs.s3.awsAccessKeyId", myAccessKey)
hadoopConf.set("fs.s3.awsSecretAccessKey", mySecretKey)

# %% [markdown]
# ### Let's explore the `user` table

# %%
user = sqlContext.read.parquet("s3://matters-analytics-dev/ETL/output_pg/user.parquet/")
user.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- uuid: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- avatar: long (nullable = true)
#  |-- email: string (nullable = true)
#  |-- email_verified: boolean (nullable = true)
#  |-- mobile: string (nullable = true)
#  |-- password_hash: string (nullable = true)
#  |-- read_speed: integer (nullable = true)
#  |-- base_gravity: integer (nullable = true)
#  |-- curr_gravity: integer (nullable = true)
#  |-- language: string (nullable = true)
#  |-- role: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
user1 = user.select(user.display_name.alias("displayName"), user.description, user.created_at.alias("registerTime")).cache()

# %%
user1.show()
# Out:
# +-----------+-------------------------------------+--------------------+
# |displayName|                          description|        registerTime|
# +-----------+-------------------------------------+--------------------+
# |     test 3|                 test user 3 descr...|2019-01-12 06:57:...|
# |     test 4|                                 null|2019-01-12 06:57:...|
# |    admin 1|                                 null|2019-01-12 06:57:...|
# |    ftggggg|                                 null|2019-01-12 09:34:...|
# |       思聰|                                 null|2017-12-04 15:13:...|
# |     Edward|                                 null|2017-11-30 06:27:...|
# |       佳禾|                                     |2017-12-04 15:27:...|
# |     方可成|                                 null|2017-12-04 15:50:...|
# |       映昕|                                 null|2017-12-04 15:59:...|
# |     黃哲斌|                                 null|2017-12-04 22:12:...|
# |       Andy|                           寫東西的人|2017-11-30 05:07:...|
# |      Isaac|                              I,Robot|2017-11-30 05:26:...|
# |      Beryl|                                 null|2017-12-01 03:06:...|
# |      Yuhan|                                 null|2017-12-01 08:31:...|
# |       潔平|                                 null|2017-12-03 03:22:...|
# |       曉雅|                                 null|2017-12-04 09:39:...|
# |     swpave|宅爸，跑者，短髮控，知名海溝學者，...|2017-12-04 22:59:...|
# |     huyong|                                 null|2017-12-04 23:51:...|
# |       欣潔|                                 null|2017-12-05 08:04:...|
# |       學展|學展，政治工作者。台灣中壢人，是七...|2017-12-05 09:02:...|
# +-----------+-------------------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Comfortable with Pandas?

# %%
userpd = user1.toPandas()

# %%
userpd.head()
# Out:
#   displayName              description               registerTime
# 0      test 3  test user 3 description 2019-01-12 06:57:01.254902
# 1      test 4                     None 2019-01-12 06:57:01.254902
# 2     admin 1                     None 2019-01-12 06:57:01.254902
# 3     ftggggg                     None 2019-01-12 09:34:50.909537
# 4          思聰                     None 2017-12-04 15:13:11.655000

# %% [markdown]
# ### Visualize through `plotly`

# %%
import plotly
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# plot a histogram of users' register time
data = [go.Histogram(x=userpd['registerTime'])]

# with interactive plot `iplot` you can interact with the graph
plotly.offline.iplot(data, filename='User register time histogram')
# Out:
# <div id="606d2545-36e8-43af-b48e-9d485810a690" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("606d2545-36e8-43af-b48e-9d485810a690", [{"x": ["2019-01-12 06:57:01.254902", "2019-01-12 06:57:01.254902", "2019-01-12 06:57:01.254902", "2019-01-12 09:34:50.909537", "2017-12-04 15:13:11.655000", "2017-11-30 06:27:22.780000", "2017-12-04 15:27:17.183000", "2017-12-04 15:50:02.499000", "2017-12-04 15:59:41.016000", "2017-12-04 22:12:20.024000", "2017-11-30 05:07:14.355000", "2017-11-30 05:26:45.041000", "2017-12-01 03:06:47.704000", "2017-12-01 08:31:15.562000", "2017-12-03 03:22:44.255000", "2017-12-04 09:39:16.105000", "2017-12-04 22:59:19.788000", "2017-12-04 23:51:50.012000", "2017-12-05 08:04:00.698000", "2017-12-05 09:02:33.333000", "2017-12-05 13:57:54.386000", "2017-12-06 01:31:10.341000", "2017-12-06 05:10:00.418000", "2017-12-06 05:19:42.226000", "2017-12-06 06:42:46.589000", "2017-12-06 07:04:18.665000", "2017-12-06 08:14:39.729000", "2017-12-06 10:15:29.531000", "2017-12-07 04:07:36.109000", "2017-12-07 06:47:41.695000", "2019-01-12 06:57:01.254902", "2019-01-14 12:51:56.216581", "2019-01-13 17:20:20.595213", "2017-12-08 01:39:11.263000", "2017-12-10 03:21:35.355000", "2017-12-18 05:44:02.557000", "2017-12-18 08:19:36.533000", "2017-12-18 12:40:08.760000", "2017-12-18 12:42:48.182000", "2017-12-18 13:31:07.601000", "2017-12-18 13:33:51.154000", "2017-12-18 16:48:25