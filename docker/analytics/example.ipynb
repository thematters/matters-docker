# %% [markdown]
# ### Load your AWS Access Key/Secret.
#
# **Never paste your Key/Secret into the notebook. Never print your Key/Secret in the notebook. Never commit your Key/Secret to github.**

# %%
import os
myAccessKey = None
mySecretKey = None
def get_secrets():
    global myAccessKey
    global mySecretKey
    myAccessKey = os.environ['AWS_ACCESS_KEY_ID']
    mySecretKey = os.environ['AWS_SECRET_ACCESS_KEY']

get_secrets()

# %% [markdown]
# ### Set up the Spark Context and AWS S3 credentials
#
# Reference:
#
# [Connecting to PySpark from a Notebook](https://jupyter-docker-stacks.readthedocs.io/en/latest/using/specifics.html#in-a-python-notebook)
#
# [Using PySpark with AWS S3](https://jupyter-docker-stacks.readthedocs.io/en/latest/using/recipes.html#using-pyspark-with-aws-s3)

# %%
# this will take some time
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.amazonaws:aws-java-sdk:1.10.34,org.apache.hadoop:hadoop-aws:2.6.0 pyspark-shell'

import pyspark
sc = pyspark.SparkContext("local[*]")

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

hadoopConf = sc._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3.impl", "org.apache.hadoop.fs.s3native.NativeS3FileSystem")
hadoopConf.set("fs.s3.awsAccessKeyId", myAccessKey)
hadoopConf.set("fs.s3.awsSecretAccessKey", mySecretKey)

# %% [markdown]
# ### Let's explore some data

# %%
user = sqlContext.read.json("s3://matters-analytics-dev/ETL/output/user.json/")
user.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)
#  |-- accountName: string (nullable = true)
#  |-- avatar: string (nullable = true)
#  |-- baseGravity: long (nullable = true)
#  |-- bio: string (nullable = true)
#  |-- derivatives: struct (nullable = true)
#  |    |-- indexKeywords: string (nullable = true)
#  |    |-- lastContributionTime: double (nullable = true)
#  |    |-- posts: struct (nullable = true)
#  |    |    |-- article: long (nullable = true)
#  |    |    |-- comment: long (nullable = true)
#  |    |-- serial: long (nullable = true)
#  |-- displayName: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- everReadPosts: boolean (nullable = true)
#  |-- geographicalData: struct (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- planet: string (nullable = true)
#  |-- gravity: long (nullable = true)
#  |-- groups: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- hashType: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- issuedInitialGift: boolean (nullable = true)
#  |-- lastConnectionTime: double (nullable = true)
#  |-- matters: long (nullable = true)
#  |-- mattersSummary: struct (nullable = true)
#  |    |-- everReceivedMatters: long (nullable = true)
#  |    |-- updateTime: double (nullable = true)
#  |-- officialBio: string (nullable = true)
#  |-- onboardingStatus: string (nullable = true)
#  |-- passwordHash: string (nullable = true)
#  |-- passwordLastChangeTime: double (nullable = true)
#  |-- preferences: struct (nullable = true)
#  |    |-- hideMobileInternalChannelInfo: boolean (nullable = true)
#  |    |-- internalPostDataView: boolean (nullable = true)
#  |    |-- internalSiteDataView: boolean (nullable = true)
#  |    |-- notificationSettings: struct (nullable = true)
#  |    |    |-- appreciationNotificationFrequency: string (nullable = true)
#  |    |    |-- enableEmailNotification: boolean (nullable = true)
#  |    |    |-- mentionNotificationFrequency: string (nullable = true)
#  |    |    |-- postPermissionChangeNotificationFrequency: string (nullable = true)
#  |    |    |-- subscriptionNotificationFrequency: string (nullable = true)
#  |    |-- subscriptionSettings: struct (nullable = true)
#  |    |    |-- subscribeArticle: boolean (nullable = true)
#  |    |    |-- subscribeComment: boolean (nullable = true)
#  |    |-- uiLanguage: string (nullable = true)
#  |-- ratings: struct (nullable = true)
#  |    |-- 06d58243-834a-4b68-878b-455a5738115d: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 0b134185-04f7-4431-931a-0c289fcfb657: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 113c2d0d-457b-452b-9480-378c3cb3a9c8: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 1316a062-1f66-437c-9c43-bf7e20852780: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 24f83787-24cd-4c24-b17a-27491c2da76d: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 348061e8-57ca-4103-ad42-43dca77fb6ec: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 7c88c092-3c22-4c52-8032-6515a9eece57: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 7e740e6c-89cf-472b-b437-a621b26726e0: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 988a2d11-5620-4e8e-b202-a6c05919dca1: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- 9b727c2a-0da2-4adc-b307-16eec8f5be1a: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- a02ce6a9-bd1a-4fde-b601-b96be3eb13b9: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- add47cd2-9f62-437a-b9ee-f05e01c7bb26: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- d6d1e647-95df-4bee-84a9-d502e7b76aee: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- d75d6165-1c82-4d16-92cf-0aeb583c27ca: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- e5efb8ac-d8c8-409d-8812-5ecf962c21a4: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- f3554ffe-7de0-4af7-b4d7-41fe7b6e84e1: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |    |-- f7d804f1-5756-4c2e-8db8-86108b116da6: struct (nullable = true)
#  |    |    |-- humour: long (nullable = true)
#  |    |    |-- objective: long (nullable = true)
#  |-- realizedSponsorLevel: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- registerTime: double (nullable = true)
#  |-- status: struct (nullable = true)
#  |    |-- disabled: boolean (nullable = true)

# %%
# registerTime in the data is millisecond in float, convert it to timestamp
from pyspark.sql.types import LongType, TimestampType
def ms2ts(col):
    return (col / 1000).cast(LongType()).cast(TimestampType())

# %%
user1 = user.select(user.displayName, user.bio, ms2ts(user.registerTime).alias("registerTime")).cache()

# %%
user1.show()
# Out:
# +-----------+-------------------------------------+-------------------+
# |displayName|                                  bio|       registerTime|
# +-----------+-------------------------------------+-------------------+
# |       Andy|                           寫東西的人|2017-11-30 05:07:14|
# |      Isaac|                              I,Robot|2017-11-30 05:26:45|
# |     Edward|                                 null|2017-11-30 06:27:22|
# |      Beryl|                                     |2017-12-01 03:06:47|
# |      Yuhan|                                     |2017-12-01 08:31:15|
# |       潔平|                                     |2017-12-03 03:22:44|
# |       曉雅|                                     |2017-12-04 09:39:16|
# |       思聰|                                     |2017-12-04 15:13:11|
# |       佳禾|                                     |2017-12-04 15:27:17|
# |     方可成|                                     |2017-12-04 15:50:02|
# |       映昕|                                     |2017-12-04 15:59:41|
# |     黃哲斌|                                     |2017-12-04 22:12:20|
# |     swpave|宅爸，跑者，短髮控，知名海溝學者，...|2017-12-04 22:59:19|
# |     huyong|                                     |2017-12-04 23:51:50|
# |       欣潔|                                     |2017-12-05 08:04:00|
# |       學展|學展，政治工作者。台灣中壢人，是七...|2017-12-05 09:02:33|
# |   ckxpress|               LikeCoin、oice、Lak...|2017-12-05 13:57:54|
# |     柴子文|                                     |2017-12-06 01:31:10|
# |       福樹|                                     |2017-12-06 05:10:00|
# |     徐小童|                                     |2017-12-06 05:19:42|
# +-----------+-------------------------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Comfortable with Pandas?

# %%
import pandas
import plotly
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = user1.toPandas()

# %%
df.head()
# Out:
#   displayName      bio        registerTime
# 0        Andy    寫東西的人 2017-11-30 05:07:14
# 1       Isaac  I,Robot 2017-11-30 05:26:45
# 2      Edward     None 2017-11-30 06:27:22
# 3       Beryl          2017-12-01 03:06:47
# 4       Yuhan          2017-12-01 08:31:15

# %%
import numpy as np
data = [go.Histogram(x=df['registerTime'])]

plotly.offline.plot(data, filename='User register time histogram')
# Out:
# /opt/conda/lib/python3.6/site-packages/plotly/offline/offline.py:635: UserWarning:
#
# Your filename `User register time histogram` didn't end with .html. Adding .html to the end of your file.
# 'file:///home/jovyan/work/User register time histogram.html'

# %%
plotly.offline.iplot(data, filename='User register time histogram')
# Out:
# <div id="3db7b464-7f24-4b7c-b420-bcfb5e005c6b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3db7b464-7f24-4b7c-b420-bcfb5e005c6b", [{"x": ["2017-11-30 05:07:14", "2017-11-30 05:26:45", "2017-11-30 06:27:22", "2017-12-01 03:06:47", "2017-12-01 08:31:15", "2017-12-03 03:22:44", "2017-12-04 09:39:16", "2017-12-04 15:13:11", "2017-12-04 15:27:17", "2017-12-04 15:50:02", "2017-12-04 15:59:41", "2017-12-04 22:12:20", "2017-12-04 22:59:19", "2017-12-04 23:51:50", "2017-12-05 08:04:00", "2017-12-05 09:02:33", "2017-12-05 13:57:54", "2017-12-06 01:31:10", "2017-12-06 05:10:00", "2017-12-06 05:19:42", "2017-12-06 06:42:46", "2017-12-06 07:04:18", "2017-12-06 08:14:39", "2017-12-06 10:15:29", "2017-12-07 04:07:36", "2017-12-07 06:47:41", "2017-12-08 01:39:11", "2017-12-08 04:46:48", "2017-12-08 05:23:04", "2017-12-10 03:21:35", "2017-12-10 09:31:19", "2017-12-12 05:40:32", "2017-12-14 10:15:08", "2017-12-17 02:10:20", "2017-12-18 02:28:39", "2017-12-18 02:57:08", "2017-12-18 05:44:02", "2017-12-18 08:19:36", "2017-12-18 12:40:08", "2017-12-18 12:42:48", "2017-12-18 13:31:07", "2017-12-18 13:33:51", "2017-12-18 16:48:25", "2017-12-18 17:16:40", "2017-12-19 01:08:40", "2017-12-19 04:07:42", "2017-12-20 05:58:28", "2017-12-20 10:46:00", "2017-12-21 04:22:08", "2017-12-21 04:56:38", "2017-12-22 16:46:05", "2017-12-27 16:45:38", "2017-12-28 04:12:04", "2017-12-28 07:37:43", "2017-12-29 18: